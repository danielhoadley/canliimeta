# %%
import pandas as pd
import requests

df = pd.read_csv('scc-2000.csv')

# %%
print (df)
# Out:
#      databaseId        caseId/en  \
# 0       csc-scc        2018scc13
# 1       csc-scc        2018scc12
# 2       csc-scc        2018scc11
# 3       csc-scc        2018scc10
# 4       csc-scc         2018scc9
# 5       csc-scc         2018scc7
# 6       csc-scc         2018scc8
# 7       csc-scc         2018scc6
# 8       csc-scc         2018scc5
# 9       csc-scc         2018scc4
# 10      csc-scc         2018scc3
# 11      csc-scc         2018scc2
# 12      csc-scc         2018scc1
# 13      csc-scc        2017scc64
# 14      csc-scc        2017scc63
# 15      csc-scc        2017scc62
# 16      csc-scc        2017scc61
# 17      csc-scc        2017scc60
# 18      csc-scc        2017scc59
# 19      csc-scc        2017scc58
# 20      csc-scc  2017canlii80438
# 21      csc-scc  2017canlii80437
# 22      csc-scc        2017scc57
# 23      csc-scc        2017scc56
# 24      csc-scc        2017scc55
# 25      csc-scc        2017scc54
# 26      csc-scc        2017scc53
# 27      csc-scc        2017scc52
# 28      csc-scc        2017scc51
# 29      csc-scc        2017scc50
# ...         ...              ...
# 1971    csc-scc     1993canlii73
# 1972    csc-scc     1993canlii72
# 1973    csc-scc     1993canlii71
# 1974    csc-scc     1993canlii70
# 1975    csc-scc     1993canlii69
# 1976    csc-scc     1993canlii68
# 1977    csc-scc     1993canlii67
# 1978    csc-scc     1993canlii66
# 1979    csc-scc     1993canlii65
# 1980    csc-scc     1993canlii64
# 1981    csc-scc     1993canlii63
# 1982    csc-scc     1993canlii62
# 1983    csc-scc     1993canlii61
# 1984    csc-scc     1993canlii60
# 1985    csc-scc     1993canlii59
# 1986    csc-scc     1993canlii58
# 1987    csc-scc     1993canlii57
# 1988    csc-scc    1993canlii115
# 1989    csc-scc    1993canlii114
# 1990    csc-scc    1993canlii113
# 1991    csc-scc    1993canlii112
# 1992    csc-scc    1993canlii111
# 1993    csc-scc    1993canlii110
# 1994    csc-scc    1993canlii109
# 1995    csc-scc    1993canlii108
# 1996    csc-scc    1993canlii106
# 1997    csc-scc    1993canlii105
# 1998    csc-scc    1993canlii104
# 1999    csc-scc    1993canlii103
# 2000    csc-scc    1993canlii102
#
#                                                   title  \
# 0                         R.A. v. Her Majesty The Queen
# 1                                          R. v. Carson
# 2     International Brotherhood of Electrical Worker...
# 3                                           R. v. Black
# 4                                          R. v. A.G.W.
# 5                                          R. v. G.T.D.
# 6     Valard Construction Ltd. v. Bird Construction Co.
# 7                                        R. v. A.R.J.D.
# 8                     R. v. Canadian Broadcasting Corp.
# 9     Williams Lake Indian Band v. Canada (Aborigina...
# 10    Quebec (Commission des normes, de l’équité, de...
# 11                       Delta Air Lines Inc. v. Lukács
# 12                                          R. v. Seipp
# 13                                      R. v. Boutilier
# 14       Deloitte & Touche v. Livent Inc. (Receiver of)
# 15    British Columbia Human Rights Tribunal v. Schrenk
# 16                               Cowper‑Smith v. Morgan
# 17                                          R. v. Jones
# 18                                        R. v. Marakah
# 19              First Nation of Nacho Nyak Dun v. Yukon
# 20                                         R. v. Jordan
# 21                                         R. v. Magoon
# 22                                       R. v. Sciascia
# 23       Barreau du Québec v. Quebec (Attorney General)
# 24    Association of Justice Counsel v. Canada (Atto...
# 25    Ktunaxa Nation v. British Columbia (Forests, L...
# 26                                     R. v. Millington
# 27                                       R. v. Robinson
# 28                  Teva Canada Ltd. v. TD Canada Trust
# 29    Tran v. Canada (Public Safety and Emergency Pr...
# ...                                                 ...
# 1971                  Slattery (Trustee of) v. Slattery
# 1972  Ontario Hydro v. Ontario (Labour Relations Board)
# 1973                                    R. v. Harbottle
# 1974                                        R. v. Plant
# 1975                                        R. v. Wiley
# 1976                                        R. v. Grant
# 1977  Edgeworth Construction Ltd. v. N. D. Lea & Ass...
# 1978  Auto Concrete Curb Ltd. v. South Nation River ...
# 1979                                    R. v. E. (A.W.)
# 1980                                       R. v. Naglik
# 1981                                       R. v. Finlay
# 1982                                       R. v. Gosset
# 1983                                    R. v. Creighton
# 1984                     Ramsden v. Peterborough (City)
# 1985                Murphy v. Welsh; Stoddard v. Watson
# 1986  Haig v. Canada; Haig v. Canada (Chief Electora...
# 1987                                      R. v. Tortone
# 1988                                     R. v. Tremblay
# 1989                                        R. v. Brown
# 1990                                       R. v. Potvin
# 1991            Weatherall v. Canada (Attorney General)
# 1992                                       R. v. Frazer
# 1993                                    R. v. Gallagher
# 1994                                    R. v. V. (K.B.)
# 1995  Saint-Basile, Village Sud (Corporation municip...
# 1996  Domtar Inc. v. Quebec (Commission d'appel en m...
# 1997                  Canada (Attorney General) v. Ward
# 1998                           Flieger v. New Brunswick
# 1999                                     R. v. Erickson
# 2000                                        R. v. Evans
#
#                                      citation
# 0                        2018 SCC 13 (CanLII)
# 1                        2018 SCC 12 (CanLII)
# 2                        2018 SCC 11 (CanLII)
# 3                        2018 SCC 10 (CanLII)
# 4                         2018 SCC 9 (CanLII)
# 5                         2018 SCC 7 (CanLII)
# 6                         2018 SCC 8 (CanLII)
# 7                         2018 SCC 6 (CanLII)
# 8                         2018 SCC 5 (CanLII)
# 9                         2018 SCC 4 (CanLII)
# 10                        2018 SCC 3 (CanLII)
# 11                        2018 SCC 2 (CanLII)
# 12                        2018 SCC 1 (CanLII)
# 13     [2017] 2 SCR 936, 2017 SCC 64 (CanLII)
# 14     [2017] 2 SCR 795, 2017 SCC 63 (CanLII)
# 15     [2017] 2 SCR 795, 2017 SCC 62 (CanLII)
# 16     [2017] 2 SCR 754, 2017 SCC 61 (CanLII)
# 17     [2017] 2 SCR 696, 2017 SCC 60 (CanLII)
# 18     [2017] 2 SCR 608, 2017 SCC 59 (CanLII)
# 19     [2017] 2 SCR 576, 2017 SCC 58 (CanLII)
# 20                    2017 CanLII 80438 (SCC)
# 21                    2017 CanLII 80437 (SCC)
# 22     [2017] 2 SCR 539, 2017 SCC 57 (CanLII)
# 23     [2017] 2 SCR 488, 2017 SCC 56 (CanLII)
# 24     [2017] 2 SCR 456, 2017 SCC 55 (CanLII)
# 25     [2017] 2 SCR 386, 2017 SCC 54 (CanLII)
# 26     [2017] 2 SCR 384, 2017 SCC 53 (CanLII)
# 27     [2017] 2 SCR 382, 2017 SCC 52 (CanLII)
# 28     [2017] 2 SCR 317, 2017 SCC 51 (CanLII)
# 29     [2017] 2 SCR 289, 2017 SCC 50 (CanLII)
# ...                                       ...
# 1971   [1993] 3 SCR 430, 1993 CanLII 73 (SCC)
# 1972   [1993] 3 SCR 327, 1993 CanLII 72 (SCC)
# 1973   [1993] 3 SCR 306, 1993 CanLII 71 (SCC)
# 1974   [1993] 3 SCR 281, 1993 CanLII 70 (SCC)
# 1975   [1993] 3 SCR 263, 1993 CanLII 69 (SCC)
# 1976   [1993] 3 SCR 223, 1993 CanLII 68 (SCC)
# 1977   [1993] 3 SCR 206, 1993 CanLII 67 (SCC)
# 1978   [1993] 3 SCR 201, 1993 CanLII 66 (SCC)
# 1979   [1993] 3 SCR 155, 1993 CanLII 65 (SCC)
# 1980   [1993] 3 SCR 122, 1993 CanLII 64 (SCC)
# 1981   [1993] 3 SCR 103, 1993 CanLII 63 (SCC)
# 1982    [1993] 3 SCR 76, 1993 CanLII 62 (SCC)
# 1983     [1993] 3 SCR 3, 1993 CanLII 61 (SCC)
# 1984  [1993] 2 SCR 1084, 1993 CanLII 60 (SCC)
# 1985  [1993] 2 SCR 1069, 1993 CanLII 59 (SCC)
# 1986   [1993] 2 SCR 995, 1993 CanLII 58 (SCC)
# 1987   [1993] 2 SCR 973, 1993 CanLII 57 (SCC)
# 1988  [1993] 2 SCR 932, 1993 CanLII 115 (SCC)
# 1989  [1993] 2 SCR 918, 1993 CanLII 114 (SCC)
# 1990  [1993] 2 SCR 880, 1993 CanLII 113 (SCC)
# 1991  [1993] 2 SCR 872, 1993 CanLII 112 (SCC)
# 1992  [1993] 2 SCR 866, 1993 CanLII 111 (SCC)
# 1993  [1993] 2 SCR 861, 1993 CanLII 110 (SCC)
# 1994  [1993] 2 SCR 857, 1993 CanLII 109 (SCC)
# 1995  [1993] 2 SCR 823, 1993 CanLII 108 (SCC)
# 1996  [1993] 2 SCR 756, 1993 CanLII 106 (SCC)
# 1997  [1993] 2 SCR 689, 1993 CanLII 105 (SCC)
# 1998  [1993] 2 SCR 651, 1993 CanLII 104 (SCC)
# 1999  [1993] 2 SCR 649, 1993 CanLII 103 (SCC)
# 2000  [1993] 2 SCR 629, 1993 CanLII 102 (SCC)
#
# [2001 rows x 4 columns]

# %%
output_file = open('scc-2000-metadata.json', 'a')

# %%
for id in df['caseId/en']:
    url = 'http://api.canlii.org/v1/caseBrowse/en/csc-scc/' + id
    
    querystring = {"api_key":"6gauat4nerh7ysgvv2t77nu4"}
    
    headers = {
    'cache-control': "no-cache",
    'postman-token': "09e93bf4-7d92-f13a-a577-e57f84174b05"
    }
    
    response = requests.request("GET", url, headers=headers, params=querystring)
    
    print(response.text)
    
    output_file.write(response.text + '\n')
# Out:
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc13",
#   "url": "http://canlii.ca/t/hr6px",
#   "title": "R.A. v. Her Majesty The Queen",
#   "citation": "2018 SCC 13 (CanLII)",
#   "language": "en",
#   "docketNumber": "37757",
#   "decisionDate": "2018-03-26",
#   "keywords": "pourvoi — majoritaires — dissident — dissenting — interjeté"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc12",
#   "url": "http://canlii.ca/t/hr51s",
#   "title": "R. v. Carson",
#   "citation": "2018 SCC 12 (CanLII)",
#   "language": "en",
#   "docketNumber": "37506",
#   "decisionDate": "2018-03-23",
#   "keywords": "business relating to the government — influence — point-of-use water treatment systems — offence — integrity"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc11",
#   "url": "http://canlii.ca/t/hr3ww",
#   "title": "International Brotherhood of Electrical Workers (IBEW) Local 773 v. Lawrence",
#   "citation": "2018 SCC 11 (CanLII)",
#   "language": "en",
#   "docketNumber": "37617",
#   "decisionDate": "2018-03-21",
#   "keywords": "pourvoi — dissidente — dismisses — dissenting — interjeté"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc10",
#   "url": "http://canlii.ca/t/hr0z4",
#   "title": "R. v. Black",
#   "citation": "2018 SCC 10 (CanLII)",
#   "language": "en",
#   "docketNumber": "37665",
#   "decisionDate": "2018-03-15",
#   "keywords": "importé — réglementant — dissidente — fail — fondements"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc9",
#   "url": "http://canlii.ca/t/hqgpd",
#   "title": "R. v. A.G.W.",
#   "citation": "2018 SCC 9 (CanLII)",
#   "language": "en",
#   "docketNumber": "37795",
#   "decisionDate": "2018-02-19",
#   "keywords": "majoritaires — interjeté — oralement — exposés — orally"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc7",
#   "url": "http://canlii.ca/t/hqh5j",
#   "title": "R. v. G.T.D.",
#   "citation": "2018 SCC 7 (CanLII)",
#   "language": "en",
#   "docketNumber": "37756",
#   "decisionDate": "2018-02-19",
#   "keywords": "surseoir à l enquête — mise en garde habituelle — violation — police — garanti"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc8",
#   "url": "http://canlii.ca/t/hqf44",
#   "title": "Valard Construction Ltd. v. Bird Construction Co.",
#   "citation": "2018 SCC 8 (CanLII)",
#   "language": "en",
#   "docketNumber": "37272",
#   "decisionDate": "2018-02-15",
#   "keywords": "bond — trust — beneficiaries — material payment bonds — existence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc6",
#   "url": "http://canlii.ca/t/hqdb3",
#   "title": "R. v. A.R.J.D.",
#   "citation": "2018 SCC 6 (CanLII)",
#   "language": "en",
#   "docketNumber": "37715",
#   "decisionDate": "2018-02-13",
#   "keywords": "tende — sexuelle — majority — belle-fille — stepdaughter"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc5",
#   "url": "http://canlii.ca/t/hq979",
#   "title": "R. v. Canadian Broadcasting Corp.",
#   "citation": "2018 SCC 5 (CanLII)",
#   "language": "en",
#   "docketNumber": "37360",
#   "decisionDate": "2018-02-09",
#   "keywords": "criminal contempt — strong prima facie — mandatory interlocutory injunction — website — publication ban"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc4",
#   "url": "http://canlii.ca/t/hq5df",
#   "title": "Williams Lake Indian Band v. Canada (Aboriginal Affairs and Northern Development)",
#   "citation": "2018 SCC 4 (CanLII)",
#   "language": "en",
#   "docketNumber": "36983",
#   "decisionDate": "2018-02-02",
#   "keywords": "band — fiduciary obligation — sui generis fiduciary — reserve — interest"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc3",
#   "url": "http://canlii.ca/t/hq4jm",
#   "title": "Quebec (Commission des normes, de l’équité, de la santé et de la sécurité du travail) v. Caron",
#   "citation": "2018 SCC 3 (CanLII)",
#   "language": "en",
#   "docketNumber": "36605",
#   "decisionDate": "2018-02-01",
#   "keywords": "suitable employment — duty to reasonably accommodate — worker — pre-injury employment — scheme"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc2",
#   "url": "http://canlii.ca/t/hpv4d",
#   "title": "Delta Air Lines Inc. v. Lukács",
#   "citation": "2018 SCC 2 (CanLII)",
#   "language": "en",
#   "docketNumber": "37276",
#   "decisionDate": "2018-01-19",
#   "keywords": "public interest standing — complaint — gatekeeping — discretion — test"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2018scc1",
#   "url": "http://canlii.ca/t/hpswj",
#   "title": "R. v. Seipp",
#   "citation": "2018 SCC 1 (CanLII)",
#   "language": "en",
#   "docketNumber": "37513",
#   "decisionDate": "2018-01-18",
#   "keywords": "accident — fui — échapper à toute responsabilité civile — contrôle d un véhicule impliqué — scene"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc64",
#   "url": "http://canlii.ca/t/hpg4c",
#   "title": "R. v. Boutilier",
#   "citation": "[2017] 2 SCR 936, 2017 SCC 64 (CanLII)",
#   "language": "en",
#   "docketNumber": "37168",
#   "decisionDate": "2017-12-21",
#   "keywords": "sentencing — indeterminate detention — dangerous offender — designation — long-term offender"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc63",
#   "url": "http://canlii.ca/t/hpdq9",
#   "title": "Deloitte \u0026 Touche v. Livent Inc. (Receiver of)",
#   "citation": "[2017] 2 SCR 795, 2017 SCC 63 (CanLII)",
#   "language": "en",
#   "docketNumber": "36875",
#   "decisionDate": "2017-12-20",
#   "keywords": "duty of care — audit — liability — reasonably foreseeable — shareholders"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc62",
#   "url": "http://canlii.ca/t/hpb2k",
#   "title": "British Columbia Human Rights Tribunal v. Schrenk",
#   "citation": "[2017] 2 SCR 795, 2017 SCC 62 (CanLII)",
#   "language": "en",
#   "docketNumber": "37041",
#   "decisionDate": "2017-12-15",
#   "keywords": "discrimination regarding employment — workplace — person — complaint — relationship"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc61",
#   "url": "http://canlii.ca/t/hp9mm",
#   "title": "Cowper‑Smith v. Morgan",
#   "citation": "[2017] 2 SCR 754, 2017 SCC 61 (CanLII)",
#   "language": "en",
#   "docketNumber": "37120",
#   "decisionDate": "2017-12-14",
#   "keywords": "proprietary estoppel — equity — promisor — interest in the property — specie distribution"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc60",
#   "url": "http://canlii.ca/t/hp63x",
#   "title": "R. v. Jones",
#   "citation": "[2017] 2 SCR 696, 2017 SCC 60 (CanLII)",
#   "language": "en",
#   "docketNumber": "37194",
#   "decisionDate": "2017-12-08",
#   "keywords": "service provider — intercept — historical text messages — reasonable expectation of privacy — authorization"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc59",
#   "url": "http://canlii.ca/t/hp63v",
#   "title": "R. v. Marakah",
#   "citation": "[2017] 2 SCR 608, 2017 SCC 59 (CanLII)",
#   "language": "en",
#   "docketNumber": "37118",
#   "decisionDate": "2017-12-08",
#   "keywords": "text messages — search — text message conversations — reasonable expectation of personal privacy — electronic conversation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc58",
#   "url": "http://canlii.ca/t/hp2d8",
#   "title": "First Nation of Nacho Nyak Dun v. Yukon",
#   "citation": "[2017] 2 SCR 576, 2017 SCC 58 (CanLII)",
#   "language": "en",
#   "docketNumber": "36779",
#   "decisionDate": "2017-12-01",
#   "keywords": "land use plan approval process — modern treaties — modify — consultation — reject"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017canlii80438",
#   "url": "http://canlii.ca/t/hp1cm",
#   "title": "R. v. Jordan",
#   "citation": "2017 CanLII 80438 (SCC)",
#   "language": "en",
#   "docketNumber": "37479",
#   "decisionDate": "2017-11-30",
#   "keywords": "suivront — interjeté — oralement — orally — daté"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017canlii80437",
#   "url": "http://canlii.ca/t/hp1ck",
#   "title": "R. v. Magoon",
#   "citation": "2017 CanLII 80437 (SCC)",
#   "language": "en",
#   "docketNumber": "37416",
#   "decisionDate": "2017-11-30",
#   "keywords": "suivront — interjeté — oralement — orally — daté"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc57",
#   "url": "http://canlii.ca/t/hnvzp",
#   "title": "R. v. Sciascia",
#   "citation": "[2017] 2 SCR 539, 2017 SCC 57 (CanLII)",
#   "language": "en",
#   "docketNumber": "37155",
#   "decisionDate": "2017-11-23",
#   "keywords": "joint — provincial offences — summary conviction criminal charges — trials — joinder"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc56",
#   "url": "http://canlii.ca/t/hn9jp",
#   "title": "Barreau du Québec v. Quebec (Attorney General)",
#   "citation": "[2017] 2 SCR 488, 2017 SCC 56 (CanLII)",
#   "language": "en",
#   "docketNumber": "37034",
#   "decisionDate": "2017-11-10",
#   "keywords": "respecting administrative justice — social affairs division — advocate — legislature — represented"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc55",
#   "url": "http://canlii.ca/t/hmvq2",
#   "title": "Association of Justice Counsel v. Canada (Attorney General)",
#   "citation": "[2017] 2 SCR 456, 2017 SCC 55 (CanLII)",
#   "language": "en",
#   "docketNumber": "37014",
#   "decisionDate": "2017-11-03",
#   "keywords": "directive — adjudicator — collective agreement — standby duty — lawyers"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc54",
#   "url": "http://canlii.ca/t/hmtxn",
#   "title": "Ktunaxa Nation v. British Columbia (Forests, Lands and Natural Resource Operations)",
#   "citation": "[2017] 2 SCR 386, 2017 SCC 54 (CanLII)",
#   "language": "en",
#   "docketNumber": "36664",
#   "decisionDate": "2017-11-02",
#   "keywords": "muk — spiritual — religious beliefs — ski resort — consultation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc53",
#   "url": "http://canlii.ca/t/hmtxk",
#   "title": "R. v. Millington",
#   "citation": "[2017] 2 SCR 384, 2017 SCC 53 (CanLII)",
#   "language": "en",
#   "docketNumber": "37235",
#   "decisionDate": "2017-11-01",
#   "keywords": "collusion — tasered — dissenting — inquest — misapprehend"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc52",
#   "url": "http://canlii.ca/t/hmtxh",
#   "title": "R. v. Robinson",
#   "citation": "[2017] 2 SCR 382, 2017 SCC 52 (CanLII)",
#   "language": "en",
#   "docketNumber": "37411",
#   "decisionDate": "2017-11-01",
#   "keywords": "dissenting — misapprehend — perjury — substantially — majority"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc51",
#   "url": "http://canlii.ca/t/hmr1p",
#   "title": "Teva Canada Ltd. v. TD Canada Trust",
#   "citation": "[2017] 2 SCR 317, 2017 SCC 51 (CanLII)",
#   "language": "en",
#   "docketNumber": "36918",
#   "decisionDate": "2017-10-27",
#   "keywords": "payee — drawer — fictitious — cheques — bearer"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc50",
#   "url": "http://canlii.ca/t/h6pmh",
#   "title": "Tran v. Canada (Public Safety and Emergency Preparedness)",
#   "citation": "[2017] 2 SCR 289, 2017 SCC 50 (CanLII)",
#   "language": "en",
#   "docketNumber": "36784",
#   "decisionDate": "2017-10-19",
#   "keywords": "maximum term of imprisonment — conditional sentences — serious criminality — punishable by a maximum term — offence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc49",
#   "url": "http://canlii.ca/t/h6mfx",
#   "title": "R. v. Bourgeois",
#   "citation": "[2017] 2 SCR 287, 2017 SCC 49 (CanLII)",
#   "language": "en",
#   "docketNumber": "37461",
#   "decisionDate": "2017-10-16",
#   "keywords": "sexual assault — verdict was unreasonable — overturning — illogical — conviction"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc48",
#   "url": "http://canlii.ca/t/h6m3w",
#   "title": "Montréal (City) v. Dorval",
#   "citation": "[2017] 2 SCR 250, 2017 SCC 48 (CanLII)",
#   "language": "en",
#   "docketNumber": "36752",
#   "decisionDate": "2017-10-13",
#   "keywords": "obligation to make reparation — physical integrity — prescriptive — interference — reparation for bodily injury caused"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc47",
#   "url": "http://canlii.ca/t/h6jgp",
#   "title": "Canada (Attorney General) v. Fontaine",
#   "citation": "[2017] 2 SCR 205, 2017 SCC 47 (CanLII)",
#   "language": "en",
#   "docketNumber": "37037",
#   "decisionDate": "2017-10-06",
#   "keywords": "supervising — claimants — archiving — residential schools — confidentiality"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc46",
#   "url": "http://canlii.ca/t/h6cf9",
#   "title": "Canada (Attorney General) v. Thouin",
#   "citation": "[2017] 2 SCR 184, 2017 SCC 46 (CanLII)",
#   "language": "en",
#   "docketNumber": "36869",
#   "decisionDate": "2017-09-28",
#   "keywords": "chief investigator — subpart — submit to discovery in proceedings — rules — lifted"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc45",
#   "url": "http://canlii.ca/t/h68g0",
#   "title": "R. v. Durham Regional Crime Stoppers Inc.",
#   "citation": "[2017] 2 SCR 157, 2017 SCC 45 (CanLII)",
#   "language": "en",
#   "docketNumber": "37052",
#   "decisionDate": "2017-09-22",
#   "keywords": "informer privilege — anonymous — intention of furthering criminal activity — interfering with the administration — police"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc44",
#   "url": "http://canlii.ca/t/h5t15",
#   "title": "India v. Badesha",
#   "citation": "[2017] 2 SCR 127, 2017 SCC 44 (CanLII)",
#   "language": "en",
#   "docketNumber": "36981",
#   "decisionDate": "2017-09-08",
#   "keywords": "substantial risk of torture — surrender — mistreatment — assurances — extradition"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc43",
#   "url": "http://canlii.ca/t/h52pq",
#   "title": "Uniprix inc. v. Gestion Gosselin et Bérubé inc.",
#   "citation": "[2017] 2 SCR 59, 2017 SCC 43 (CanLII)",
#   "language": "en",
#   "docketNumber": "36718",
#   "decisionDate": "2017-07-28",
#   "keywords": "member pharmacists — contract of affiliation — perpetual — term — renewal"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc42",
#   "url": "http://canlii.ca/t/h5201",
#   "title": "Quebec (Attorney General) v. Guérin",
#   "citation": "[2017] 2 SCR 3, 2017 SCC 42 (CanLII)",
#   "language": "en",
#   "docketNumber": "36775",
#   "decisionDate": "2017-07-27",
#   "keywords": "digitization fee — arbitrator — council of arbitration — dispute — laboratories"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc41",
#   "url": "http://canlii.ca/t/h51gx",
#   "title": "Chippewas of the Thames First Nation v. Enbridge Pipelines Inc.",
#   "citation": "[2017] 1 SCR 1099, 2017 SCC 41 (CanLII)",
#   "language": "en",
#   "docketNumber": "36776",
#   "decisionDate": "2017-07-26",
#   "keywords": "duty to consult — project — groups — treaty — pipeline"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc40",
#   "url": "http://canlii.ca/t/h51gv",
#   "title": "Clyde River (Hamlet) v. Petroleum Geo‑Services Inc.",
#   "citation": "[2017] 1 SCR 1069, 2017 SCC 40 (CanLII)",
#   "language": "en",
#   "docketNumber": "36692",
#   "decisionDate": "2017-07-26",
#   "keywords": "duty to consult — marine mammals — proponents — treaty — environmental"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc39",
#   "url": "http://canlii.ca/t/h4rzm",
#   "title": "Wilson v. Alharayeri",
#   "citation": "[2017] 1 SCR 1037, 2017 SCC 39 (CanLII)",
#   "language": "en",
#   "docketNumber": "36689",
#   "decisionDate": "2017-07-13",
#   "keywords": "oppression — director — common shares — imposition of personal liability — oppressive conduct"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc38",
#   "url": "http://canlii.ca/t/h4p6t",
#   "title": "R. v. George",
#   "citation": "[2017] 1 SCR 1021, 2017 SCC 38 (CanLII)",
#   "language": "en",
#   "docketNumber": "37372",
#   "decisionDate": "2017-07-07",
#   "keywords": "sexual activity — age — reasonable steps — acquittals — errors"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc37",
#   "url": "http://canlii.ca/t/h4mzd",
#   "title": "R. v. Alex",
#   "citation": "[2017] 1 SCR 967, 2017 SCC 37 (CanLII)",
#   "language": "en",
#   "docketNumber": "36771",
#   "decisionDate": "2017-07-06",
#   "keywords": "evidentiary shortcuts — breath — demand — sample — blood-alcohol concentration"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc36",
#   "url": "http://canlii.ca/t/h4knz",
#   "title": "AstraZeneca Canada Inc. v. Apotex Inc.",
#   "citation": "[2017] 1 SCR 943, 2017 SCC 36 (CanLII)",
#   "language": "en",
#   "docketNumber": "36654",
#   "decisionDate": "2017-06-30",
#   "keywords": "patent — invention — utility — soundly predicted — useful"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc35",
#   "url": "http://canlii.ca/t/h4jxt",
#   "title": "R. v. Bradshaw",
#   "citation": "[2017] 1 SCR 865, 2017 SCC 35 (CanLII)",
#   "language": "en",
#   "docketNumber": "36537",
#   "decisionDate": "2017-06-29",
#   "keywords": "hearsay — murders — threshold reliability — re-enactment — corroborative evidence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc34",
#   "url": "http://canlii.ca/t/h4jg2",
#   "title": "Google Inc. v. Equustek Solutions Inc.",
#   "citation": "[2017] 1 SCR 824, 2017 SCC 34 (CanLII)",
#   "language": "en",
#   "docketNumber": "36602",
#   "decisionDate": "2017-06-28",
#   "keywords": "websites — interlocutory injunction — irreparable harm — google ca — search"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc33",
#   "url": "http://canlii.ca/t/h4g1b",
#   "title": "Douez v. Facebook, Inc.",
#   "citation": "[2017] 1 SCR 751, 2017 SCC 33 (CanLII)",
#   "language": "en",
#   "docketNumber": "36616",
#   "decisionDate": "2017-06-23",
#   "keywords": "forum selection clause — strong cause — forum selection clauses — consumer — forum non conveniens"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc32",
#   "url": "http://canlii.ca/t/h4f8v",
#   "title": "Teal Cedar Products Ltd. v. British Columbia",
#   "citation": "[2017] 1 SCR 688, 2017 SCC 32 (CanLII)",
#   "language": "en",
#   "docketNumber": "36595",
#   "decisionDate": "2017-06-22",
#   "keywords": "arbitrator — improvements — compensation — value — factual matrix"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc31",
#   "url": "http://canlii.ca/t/h4bfk",
#   "title": "R. v. Cody",
#   "citation": "[2017] 1 SCR 659, 2017 SCC 31 (CanLII)",
#   "language": "en",
#   "docketNumber": "37310",
#   "decisionDate": "2017-06-16",
#   "keywords": "delay — defence — transitional exceptional circumstance — discrete — ceiling"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc30",
#   "url": "http://canlii.ca/t/h49b1",
#   "title": "Stewart v. Elk Valley Coal Corp.",
#   "citation": "[2017] 1 SCR 591, 2017 SCC 30 (CanLII)",
#   "language": "en",
#   "docketNumber": "36636",
#   "decisionDate": "2017-06-15",
#   "keywords": "prima facie discrimination — addiction — drug — termination — accommodation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc29",
#   "url": "http://canlii.ca/t/h4637",
#   "title": "Pellerin Savitz LLP v. Guindon",
#   "citation": "[2017] 1 SCR 575, 2017 SCC 29 (CanLII)",
#   "language": "en",
#   "docketNumber": "36915",
#   "decisionDate": "2017-06-09",
#   "keywords": "prescription — lawyer — client — invoice — contract"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc28",
#   "url": "http://canlii.ca/t/h42pw",
#   "title": "Saadati v. Moorhead",
#   "citation": "[2017] 1 SCR 543, 2017 SCC 28 (CanLII)",
#   "language": "en",
#   "docketNumber": "36703",
#   "decisionDate": "2017-06-02",
#   "keywords": "recognizable psychiatric illness — claimant — recovery for mental injury — accident — proximity"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc27",
#   "url": "http://canlii.ca/t/h41w4",
#   "title": "R. v. Antic",
#   "citation": "[2017] 1 SCR 509, 2017 SCC 27 (CanLII)",
#   "language": "en",
#   "docketNumber": "36783",
#   "decisionDate": "2017-06-01",
#   "keywords": "release — bail review — cash deposit — sureties — bail without just cause"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc26",
#   "url": "http://canlii.ca/t/h3q0c",
#   "title": "Quebec (Director of Criminal and Penal Prosecutions) v. Jodoin",
#   "citation": "[2017] 1 SCR 478, 2017 SCC 26 (CanLII)",
#   "language": "en",
#   "docketNumber": "36539",
#   "decisionDate": "2017-05-12",
#   "keywords": "motions for writs of prohibition — costs against a lawyer personally — conduct — criminal — exceptional"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017canlii24267",
#   "url": "http://canlii.ca/t/h3g14",
#   "title": "R. v. George",
#   "citation": "2017 CanLII 24267 (SCC)",
#   "language": "en",
#   "docketNumber": "37372",
#   "decisionDate": "2017-04-28",
#   "keywords": "acquittements — suivront — rétablir — restored — interjeté"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc25",
#   "url": "http://canlii.ca/t/h3dxl",
#   "title": "R. v. Hunt",
#   "citation": "[2017] 1 SCR 476, 2017 SCC 25 (CanLII)",
#   "language": "en",
#   "docketNumber": "37314",
#   "decisionDate": "2017-04-27",
#   "keywords": "stay of proceedings — constitutional right to security — falsifying — fraud — circulating"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc24",
#   "url": "http://canlii.ca/t/h3b2q",
#   "title": "Lajeunesse (Re)",
#   "citation": "[2017] 1 SCR 473, 2017 SCC 24 (CanLII)",
#   "language": "en",
#   "docketNumber": "37320",
#   "decisionDate": "2017-04-21",
#   "keywords": "formerly known as des lésions — notaires — appeared for the intervener — strike — québécois"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc23",
#   "url": "http://canlii.ca/t/h3993",
#   "title": "Pintea v. Johns",
#   "citation": "[2017] 1 SCR 470, 2017 SCC 23 (CanLII)",
#   "language": "en",
#   "docketNumber": "37109",
#   "decisionDate": "2017-04-18",
#   "keywords": "contempt — cso-dce — management — pdf — cjc-ccm"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc22",
#   "url": "http://canlii.ca/t/h32b7",
#   "title": "Ostiguy v. Allie",
#   "citation": "[2017] 1 SCR 402, 2017 SCC 22 (CanLII)",
#   "language": "en",
#   "docketNumber": "36694",
#   "decisionDate": "2017-04-06",
#   "keywords": "acquisitive prescription — immovable — possessor — land register — ownership"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc21",
#   "url": "http://canlii.ca/t/h3062",
#   "title": "R. v. Savard",
#   "citation": "[2017] 1 SCR 400, 2017 SCC 21 (CanLII)",
#   "language": "en",
#   "docketNumber": "36908",
#   "decisionDate": "2017-04-03",
#   "keywords": "dissenting — nephews — indecency — niece — guilty"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc19",
#   "url": "http://canlii.ca/t/h2zcs",
#   "title": "Desjardins Financial Security Life Assurance Company v. Émond",
#   "citation": "[2017] 1 SCR 358, 2017 SCC 19 (CanLII)",
#   "language": "en",
#   "docketNumber": "36919",
#   "decisionDate": "2017-03-31",
#   "keywords": "died are hybrid offences — heirs of the insured — art — accident — punishable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc20",
#   "url": "http://canlii.ca/t/h2wx1",
#   "title": "Green v. Law Society of Manitoba",
#   "citation": "[2017] 1 SCR 360, 2017 SCC 20 (CanLII)",
#   "language": "en",
#   "docketNumber": "36583",
#   "decisionDate": "2017-03-30",
#   "keywords": "impugned rules — suspension — benchers — lawyer — chief executive officer"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc18",
#   "url": "http://canlii.ca/t/hpv10",
#   "title": "Godbout v. Pagé",
#   "citation": "[2017] 1 SCR 283, 2017 SCC 18 (CanLII)",
#   "language": "en",
#   "docketNumber": "36385; 36388",
#   "decisionDate": "2017-03-24",
#   "keywords": "bodily injury — automobile accident — fault — causal link — compensation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc17",
#   "url": "http://canlii.ca/t/h2q81",
#   "title": "R. v. Oland",
#   "citation": "[2017] 1 SCR 250, 2017 SCC 17 (CanLII)",
#   "language": "en",
#   "docketNumber": "36986",
#   "decisionDate": "2017-03-23",
#   "keywords": "reviewability — bail pending — enforceability — public confidence in the administration — criterion"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc16",
#   "url": "http://canlii.ca/t/h2pkf",
#   "title": "R. v. S.B.",
#   "citation": "[2017] 1 SCR 248, 2017 SCC 16 (CanLII)",
#   "language": "en",
#   "docketNumber": "37042",
#   "decisionDate": "2017-03-22",
#   "keywords": "acquittals — sexual — assault — jury — charges"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc15",
#   "url": "http://canlii.ca/t/h1tk4",
#   "title": "R. v. Paterson",
#   "citation": "[2017] 1 SCR 202, 2017 SCC 15 (CanLII)",
#   "language": "en",
#   "docketNumber": "36472",
#   "decisionDate": "2017-03-17",
#   "keywords": "police — exigent circumstances — seize the roaches — warrantless entry — impracticable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc14",
#   "url": "http://canlii.ca/t/gxnpq",
#   "title": "R. v. Aitkens",
#   "citation": "[2017] 1 SCR 199, 2017 SCC 14 (CanLII)",
#   "language": "en",
#   "docketNumber": "36866",
#   "decisionDate": "2017-02-24",
#   "keywords": "intervener — jury — penalty — imprisonment — affirming"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc13",
#   "url": "http://canlii.ca/t/gxnpn",
#   "title": "R. v. Peers",
#   "citation": "[2017] 1 SCR 196, 2017 SCC 13 (CanLII)",
#   "language": "en",
#   "docketNumber": "36865",
#   "decisionDate": "2017-02-24",
#   "keywords": "intervener — jury — penalty — imprisonment — maximum"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc12",
#   "url": "http://canlii.ca/t/gxn04",
#   "title": "R. v. Bingley",
#   "citation": "[2017] 1 SCR 170, 2017 SCC 12 (CanLII)",
#   "language": "en",
#   "docketNumber": "36610",
#   "decisionDate": "2017-02-23",
#   "keywords": "evidence — drug — reliability — step evaluation — science"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc11",
#   "url": "http://canlii.ca/t/gxn3w",
#   "title": "R. v. Olotu",
#   "citation": "[2017] 1 SCR 168, 2017 SCC 11 (CanLII)",
#   "language": "en",
#   "docketNumber": "37167",
#   "decisionDate": "2017-02-23",
#   "keywords": "sexual assault causing bodily harm — verdict — misapprehend — evidence — illogical"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc10",
#   "url": "http://canlii.ca/t/gxlbz",
#   "title": "R. v. Brown",
#   "citation": "[2017] 1 SCR 166, 2017 SCC 10 (CanLII)",
#   "language": "en",
#   "docketNumber": "37153",
#   "decisionDate": "2017-02-21",
#   "keywords": "assault with a weapon — evidence — second degree murder — convictions — shooter"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc9",
#   "url": "http://canlii.ca/t/gxl1q",
#   "title": "R. v. Clifford",
#   "citation": "[2017] 1 SCR 164, 2017 SCC 9 (CanLII)",
#   "language": "en",
#   "docketNumber": "37140",
#   "decisionDate": "2017-02-20",
#   "keywords": "intervener — vandalism — false alibi — victims — dissenting"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc8",
#   "url": "http://canlii.ca/t/gxjs8",
#   "title": "Nelson (City) v. Mowatt",
#   "citation": "[2017] 1 SCR 138, 2017 SCC 8 (CanLII)",
#   "language": "en",
#   "docketNumber": "36999",
#   "decisionDate": "2017-02-17",
#   "keywords": "disputed lot — adverse possession — chambers — land — continuous"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc7",
#   "url": "http://canlii.ca/t/gx4t0",
#   "title": "Sabean v. Portage La Prairie Mutual Insurance Co.",
#   "citation": "[2017] 1 SCR 121, 2017 SCC 7 (CanLII)",
#   "language": "en",
#   "docketNumber": "36575",
#   "decisionDate": "2017-01-27",
#   "keywords": "cl — eligible claimant — disability benefits — amount payable by the insurer — contract"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc6",
#   "url": "http://canlii.ca/t/gx3xm",
#   "title": "B.C. Freedom of Information and Privacy Association v. British Columbia (Attorney General)",
#   "citation": "[2017] 1 SCR 93, 2017 SCC 6 (CanLII)",
#   "language": "en",
#   "docketNumber": "36495",
#   "decisionDate": "2017-01-26",
#   "keywords": "registration requirement — organization — political — individual — handmade"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc5",
#   "url": "http://canlii.ca/t/gx1r7",
#   "title": "R. v. Natewayes",
#   "citation": "[2017] 1 SCR 91, 2017 SCC 5 (CanLII)",
#   "language": "en",
#   "docketNumber": "36793",
#   "decisionDate": "2017-01-23",
#   "keywords": "entering with intent to commit — conviction for manslaughter — invasion — breaking — indictable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc4",
#   "url": "http://canlii.ca/t/gx1r5",
#   "title": "R. v. Bédard",
#   "citation": "[2017] 1 SCR 89, 2017 SCC 4 (CanLII)",
#   "language": "en",
#   "docketNumber": "37071",
#   "decisionDate": "2017-01-23",
#   "keywords": "defence of officially induced error — assault causing bodily harm — government — warrantless — guilty"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc3",
#   "url": "http://canlii.ca/t/gx0mx",
#   "title": "R. v. Clark",
#   "citation": "[2017] 1 SCR 86, 2017 SCC 3 (CanLII)",
#   "language": "en",
#   "docketNumber": "36813",
#   "decisionDate": "2017-01-19",
#   "keywords": "intervener — telewarrant — acquittals — van der — impracticability"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc2",
#   "url": "http://canlii.ca/t/gx0mr",
#   "title": "R. v. Awer",
#   "citation": "[2017] 1 SCR 83, 2017 SCC 2 (CanLII)",
#   "language": "en",
#   "docketNumber": "37021",
#   "decisionDate": "2017-01-19",
#   "keywords": "impugned evidence — scientific — expert — scrutiny — speculative"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2017scc1",
#   "url": "http://canlii.ca/t/gwvg7",
#   "title": "Ernst v. Alberta Energy Regulator",
#   "citation": "[2017] 1 SCR 3, 2017 SCC 1 (CanLII)",
#   "language": "en",
#   "docketNumber": "36167",
#   "decisionDate": "2017-01-13",
#   "keywords": "immunity clause — damages — constitutionality — quasi-judicial decision-makers — remedy"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc56",
#   "url": "http://canlii.ca/t/gvzzj",
#   "title": "Canada (Attorney General) v. Fairmont Hotels Inc.",
#   "citation": "[2016] 2 SCR 720, 2016 SCC 56 (CanLII)",
#   "language": "en",
#   "docketNumber": "36606",
#   "decisionDate": "2016-12-09",
#   "keywords": "rectification — tax — instrument — reciprocal loan — mistake"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc55",
#   "url": "http://canlii.ca/t/gvzzg",
#   "title": "Jean Coutu Group (PJC) Inc. v. Canada (Attorney General)",
#   "citation": "[2016] 2 SCR 670, 2016 SCC 55 (CanLII)",
#   "language": "en",
#   "docketNumber": "36505",
#   "decisionDate": "2016-12-09",
#   "keywords": "rectification — tax consequences — intention — transactional scheme — determinate"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc54",
#   "url": "http://canlii.ca/t/gvzbj",
#   "title": "Windsor (City) v. Canadian Transit Co.",
#   "citation": "[2016] 2 SCR 617, 2016 SCC 54 (CanLII)",
#   "language": "en",
#   "docketNumber": "36465",
#   "decisionDate": "2016-12-08",
#   "keywords": "federal — relief — statutory grant of jurisdiction — constitutional — essential to the disposition"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc53",
#   "url": "http://canlii.ca/t/gvskr",
#   "title": "Alberta (Information and Privacy Commissioner) v. University of Calgary",
#   "citation": "[2016] 2 SCR 555, 2016 SCC 53 (CanLII)",
#   "language": "en",
#   "docketNumber": "36460",
#   "decisionDate": "2016-11-25",
#   "keywords": "records over which solicitor-client privilege — public body — abrogate solicitor-client privilege — solicitor-client privilege is claimed — delegate"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc52",
#   "url": "http://canlii.ca/t/gvskp",
#   "title": "Lizotte v. Aviva Insurance Company of Canada",
#   "citation": "[2016] 2 SCR 521, 2016 SCC 52 (CanLII)",
#   "language": "en",
#   "docketNumber": "36373",
#   "decisionDate": "2016-11-25",
#   "keywords": "solicitor-client privilege — litigation privilege — syndic — professional secrecy — abrogated"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc51",
#   "url": "http://canlii.ca/t/gvp55",
#   "title": "Mennillo v. Intramodal inc.",
#   "citation": "[2016] 2 SCR 438, 2016 SCC 51 (CanLII)",
#   "language": "en",
#   "docketNumber": "36124",
#   "decisionDate": "2016-11-18",
#   "keywords": "shareholder — oppression — corporation — transfer — company"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc50",
#   "url": "http://canlii.ca/t/gvndv",
#   "title": "Royal Bank of Canada v. Trang",
#   "citation": "[2016] 2 SCR 412, 2016 SCC 50 (CanLII)",
#   "language": "en",
#   "docketNumber": "36296",
#   "decisionDate": "2016-11-17",
#   "keywords": "mortgage discharge — disclosure — creditor — information — sheriff"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc49",
#   "url": "http://canlii.ca/t/gvlgm",
#   "title": "British Columbia Teachers\u0027 Federation v. British Columbia",
#   "citation": "[2016] 2 SCR 407, 2016 SCC 49 (CanLII)",
#   "language": "en",
#   "docketNumber": "36500",
#   "decisionDate": "2016-11-10",
#   "keywords": "intervener — syndicats — teachers — legislation — collective"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc48",
#   "url": "http://canlii.ca/t/gvk2h",
#   "title": "Benhaim v. St‑Germain",
#   "citation": "[2016] 2 SCR 352, 2016 SCC 48 (CanLII)",
#   "language": "en",
#   "docketNumber": "36291",
#   "decisionDate": "2016-11-10",
#   "keywords": "lung cancer — stage — inference of causation — overriding error — evidence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc47",
#   "url": "http://canlii.ca/t/gvjqr",
#   "title": "Edmonton (City) v. Edmonton East (Capilano) Shopping Centres Ltd.",
#   "citation": "[2016] 2 SCR 293, 2016 SCC 47 (CanLII)",
#   "language": "en",
#   "docketNumber": "36403",
#   "decisionDate": "2016-11-04",
#   "keywords": "complaint — standard of review — taxpayer — assessment roll — legislature"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc46",
#   "url": "http://canlii.ca/t/gvjqm",
#   "title": "R. v. Diamond",
#   "citation": "[2016] 2 SCR 291, 2016 SCC 46 (CanLII)",
#   "language": "en",
#   "docketNumber": "36816",
#   "decisionDate": "2016-11-03",
#   "keywords": "dissenting — cocaine — seizure — arrest — visual"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc45",
#   "url": "http://canlii.ca/t/gvjqp",
#   "title": "Urban Communications Inc. v. BCNET Networking Society",
#   "citation": "[2016] 2 SCR 289, 2016 SCC 45 (CanLII)",
#   "language": "en",
#   "docketNumber": "36639",
#   "decisionDate": "2016-11-03",
#   "keywords": "reinstating — arbitrator — option to renew — validly exercised — disagreeing"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc44",
#   "url": "http://canlii.ca/t/gvblz",
#   "title": "Morasse v. Nadeau‑Dubois",
#   "citation": "[2016] 2 SCR 232, 2016 SCC 44 (CanLII)",
#   "language": "en",
#   "docketNumber": "36351",
#   "decisionDate": "2016-10-27",
#   "keywords": "contempt — students — picket lines — classes — injunction"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc43",
#   "url": "http://canlii.ca/t/gv7bk",
#   "title": "R. v. Anthony‑Cook",
#   "citation": "[2016] 2 SCR 204, 2016 SCC 43 (CanLII)",
#   "language": "en",
#   "docketNumber": "36410",
#   "decisionDate": "2016-10-21",
#   "keywords": "joint — sentence — public interest — plea — test"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc42",
#   "url": "http://canlii.ca/t/gv6g4",
#   "title": "Endean v. British Columbia",
#   "citation": "[2016] 2 SCR 162, 2016 SCC 42 (CanLII)",
#   "language": "en",
#   "docketNumber": "35843; 36456",
#   "decisionDate": "2016-10-20",
#   "keywords": "video link — open court principle — superior — inherent jurisdiction — outside"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc41",
#   "url": "http://canlii.ca/t/gv5d9",
#   "title": "R. v. C.K-D.",
#   "citation": "[2016] 2 SCR 160, 2016 SCC 41 (CanLII)",
#   "language": "en",
#   "docketNumber": "36877",
#   "decisionDate": "2016-10-18",
#   "keywords": "convictions restored — jury as a whole — year-old — sexual — instruction"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc40",
#   "url": "http://canlii.ca/t/gv5dd",
#   "title": "R. v. Rowson",
#   "citation": "[2016] 2 SCR 158, 2016 SCC 40 (CanLII)",
#   "language": "en",
#   "docketNumber": "36777",
#   "decisionDate": "2016-10-17",
#   "keywords": "driving causing bodily harm — convictions — breathalyzer — disrepute — upholding"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc39",
#   "url": "http://canlii.ca/t/gv3pl",
#   "title": "Conférence des juges de paix magistrats du Québec v. Quebec (Attorney General)",
#   "citation": "[2016] 2 SCR 116, 2016 SCC 39 (CanLII)",
#   "language": "en",
#   "docketNumber": "36165",
#   "decisionDate": "2016-10-14",
#   "keywords": "remuneration — judicial independence — justices of the peace — committee — judicial office"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc38",
#   "url": "http://canlii.ca/t/gtw6r",
#   "title": "Canada (Attorney General) v. Igloo Vikski Inc.",
#   "citation": "[2016] 2 SCR 80, 2016 SCC 38 (CanLII)",
#   "language": "en",
#   "docketNumber": "36258",
#   "decisionDate": "2016-09-29",
#   "keywords": "heading — gloves — goods — prima facie classifiable — plastics"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc37",
#   "url": "http://canlii.ca/t/gtpvn",
#   "title": "Ledcor Construction Ltd. v. Northbridge Indemnity Insurance Co.",
#   "citation": "[2016] 2 SCR 23, 2016 SCC 37 (CanLII)",
#   "language": "en",
#   "docketNumber": "36452",
#   "decisionDate": "2016-09-15",
#   "keywords": "cost of redoing the faulty — interpretation — damage — coverage — standard form"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc36",
#   "url": "http://canlii.ca/t/gt9fr",
#   "title": "Musqueam Indian Band v. Musqueam Indian Band (Board of Review)",
#   "citation": "[2016] 2 SCR 3, 2016 SCC 36 (CanLII)",
#   "language": "en",
#   "docketNumber": "36478",
#   "decisionDate": "2016-09-09",
#   "keywords": "lease — reserve lands — restriction — placed by the band — land"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc35",
#   "url": "http://canlii.ca/t/gsq38",
#   "title": "Lafortune v. Financière agricole du Québec",
#   "citation": "[2016] 1 SCR 1091, 2016 SCC 35 (CanLII)",
#   "language": "en",
#   "docketNumber": "36210",
#   "decisionDate": "2016-07-29",
#   "keywords": "study — net annual income — producers — contract of insurance — benchmark farm"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc34",
#   "url": "http://canlii.ca/t/gsq3d",
#   "title": "Ferme Vi‑Ber inc. v. Financière agricole du Québec",
#   "citation": "[2016] 1 SCR 1032, 2016 SCC 34 (CanLII)",
#   "language": "en",
#   "docketNumber": "36205",
#   "decisionDate": "2016-07-29",
#   "keywords": "amounts — benchmark farm — participants — programs — linkage"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc33",
#   "url": "http://canlii.ca/t/gsq3b",
#   "title": "R. v. Villaroman",
#   "citation": "[2016] 1 SCR 1000, 2016 SCC 33 (CanLII)",
#   "language": "en",
#   "docketNumber": "36435",
#   "decisionDate": "2016-07-29",
#   "keywords": "circumstantial evidence — child pornography — inferences — computer — reasonable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc32",
#   "url": "http://canlii.ca/t/gsmk4",
#   "title": "R. v. Cawthorne",
#   "citation": "[2016] 1 SCR 983, 2016 SCC 32 (CanLII)",
#   "language": "en",
#   "docketNumber": "36466; 36844",
#   "decisionDate": "2016-07-22",
#   "keywords": "military — declining to grant a mistrial — independently of partisan concerns — intervener — violates"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc31",
#   "url": "http://canlii.ca/t/gsm3w",
#   "title": "R. v. K.R.J.",
#   "citation": "[2016] 1 SCR 906, 2016 SCC 31 (CanLII)",
#   "language": "en",
#   "docketNumber": "36200",
#   "decisionDate": "2016-07-21",
#   "keywords": "retrospective operation — offenders — punishment — amendments — sentencing"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc30",
#   "url": "http://canlii.ca/t/gshvf",
#   "title": "Lapointe Rosenstein Marchand Melançon LLP v. Cassels Brock \u0026 Blackwell LLP",
#   "citation": "[2016] 1 SCR 851, 2016 SCC 30 (CanLII)",
#   "language": "en",
#   "docketNumber": "36087",
#   "decisionDate": "2016-07-15",
#   "keywords": "jurisdiction — dealers — fourth connecting factor — firms — contract"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc29",
#   "url": "http://canlii.ca/t/gsh2f",
#   "title": "Wilson v. Atomic Energy of Canada Ltd.",
#   "citation": "[2016] 1 SCR 770, 2016 SCC 29 (CanLII)",
#   "language": "en",
#   "docketNumber": "36354",
#   "decisionDate": "2016-07-14",
#   "keywords": "employee — unjust dismissal — federally regulated — adjudicator — lawfulness"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc28",
#   "url": "http://canlii.ca/t/gsds5",
#   "title": "R. v. Williamson",
#   "citation": "[2016] 1 SCR 741, 2016 SCC 28 (CanLII)",
#   "language": "en",
#   "docketNumber": "36112",
#   "decisionDate": "2016-07-08",
#   "keywords": "preliminary inquiry — institutional delay — defence — time — prejudice"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc27",
#   "url": "http://canlii.ca/t/gsds3",
#   "title": "R. v. Jordan",
#   "citation": "[2016] 1 SCR 631, 2016 SCC 27 (CanLII)",
#   "language": "en",
#   "docketNumber": "36068",
#   "decisionDate": "2016-07-08",
#   "keywords": "institutional delay — framework — time — defence — reasonable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc26",
#   "url": "http://canlii.ca/t/gs9r9",
#   "title": "R. v. Vassell",
#   "citation": "[2016] 1 SCR 625, 2016 SCC 26 (CanLII)",
#   "language": "en",
#   "docketNumber": "36792",
#   "decisionDate": "2016-06-30",
#   "keywords": "co-accused — delay — proactive — tried within a reasonable time — stay of proceedings"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc25",
#   "url": "http://canlii.ca/t/gs78q",
#   "title": "British Columbia (Workers’ Compensation Appeal Tribunal) v. Fraser Health Authority",
#   "citation": "[2016] 1 SCR 587, 2016 SCC 25 (CanLII)",
#   "language": "en",
#   "docketNumber": "36300",
#   "decisionDate": "2016-06-24",
#   "keywords": "breast cancer — exposures — causal link — evidence — cluster"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016canlii37772",
#   "url": "http://canlii.ca/t/gs6xp",
#   "title": "Stephen Patrick Burrows v. Her Majesty the Queen",
#   "citation": "2016 CanLII 37772 (SCC)",
#   "language": "en",
#   "docketNumber": "36929",
#   "decisionDate": "2016-06-23",
#   "keywords": "autorisation — prorogation — application for leave — numéros — accueillie"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc24",
#   "url": "http://canlii.ca/t/gs6xk",
#   "title": "R. v. Saeed",
#   "citation": "[2016] 1 SCR 518, 2016 SCC 24 (CanLII)",
#   "language": "en",
#   "docketNumber": "36328",
#   "decisionDate": "2016-06-23",
#   "keywords": "penile swab — search incident to arrest — police — genital swabs — genital swab"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc23",
#   "url": "http://canlii.ca/t/gs3l3",
#   "title": "Rogers Communications Inc. v. Châteauguay (City)",
#   "citation": "[2016] 1 SCR 467, 2016 SCC 23 (CanLII)",
#   "language": "en",
#   "docketNumber": "36027",
#   "decisionDate": "2016-06-16",
#   "keywords": "radiocommunication — notice of a reserve — doctrine of interjurisdictional immunity — antenna system — pith"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc22",
#   "url": "http://canlii.ca/t/gs0p6",
#   "title": "R. v. D.L.W.",
#   "citation": "[2016] 1 SCR 402, 2016 SCC 22 (CanLII)",
#   "language": "en",
#   "docketNumber": "36450",
#   "decisionDate": "2016-06-09",
#   "keywords": "bestiality — buggery — penetration — offence — animal"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc21",
#   "url": "http://canlii.ca/t/grxb3",
#   "title": "Canada (National Revenue) v. Thompson",
#   "citation": "[2016] 1 SCR 381, 2016 SCC 21 (CanLII)",
#   "language": "en",
#   "docketNumber": "35590",
#   "decisionDate": "2016-06-03",
#   "keywords": "definition of solicitor-client privilege — accounting records — protected by solicitor-client privilege — notaires — information"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc20",
#   "url": "http://canlii.ca/t/grxb1",
#   "title": "Canada (Attorney General) v. Chambre des notaires du Québec",
#   "citation": "[2016] 1 SCR 336, 2016 SCC 20 (CanLII)",
#   "language": "en",
#   "docketNumber": "35892",
#   "decisionDate": "2016-06-03",
#   "keywords": "notaries — protected by professional secrecy — definition of solicitor-client privilege — accounting records — information"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc19",
#   "url": "http://canlii.ca/t/gr6cd",
#   "title": "Heritage Capital Corp. v. Equitable Trust Co.",
#   "citation": "[2016] 1 SCR 306, 2016 SCC 19 (CanLII)",
#   "language": "en",
#   "docketNumber": "36301",
#   "decisionDate": "2016-05-06",
#   "keywords": "run with the land — covenant — owner — chambers — interpretation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc18",
#   "url": "http://canlii.ca/t/gr6cb",
#   "title": "Krayzel Corp. v. Equitable Trust Co.",
#   "citation": "[2016] 1 SCR 273, 2016 SCC 18 (CanLII)",
#   "language": "en",
#   "docketNumber": "36123",
#   "decisionDate": "2016-05-06",
#   "keywords": "percent — arrears — discounts — rate of interest — principal money"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc17",
#   "url": "http://canlii.ca/t/gr52c",
#   "title": "R. v. Laliberté",
#   "citation": "[2016] 1 SCR 270, 2016 SCC 17 (CanLII)",
#   "language": "en",
#   "docketNumber": "36712",
#   "decisionDate": "2016-05-03",
#   "keywords": "fabrication of an alibi — instruction — curative proviso — murder — out-of-court statements"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc16",
#   "url": "http://canlii.ca/t/gr4wj",
#   "title": "R. v. Shaoulle",
#   "citation": "[2016] 1 SCR 268, 2016 SCC 16 (CanLII)",
#   "language": "en",
#   "docketNumber": "36704",
#   "decisionDate": "2016-05-02",
#   "keywords": "conviction for first degree murder — upholding — concurring — verdict — dismissed"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc15",
#   "url": "http://canlii.ca/t/gpqgv",
#   "title": "World Bank Group v. Wallace",
#   "citation": "[2016] 1 SCR 207, 2016 SCC 15 (CanLII)",
#   "language": "en",
#   "docketNumber": "36315",
#   "decisionDate": "2016-04-29",
#   "keywords": "immunities — archives — affiant — tipsters — documents"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc14",
#   "url": "http://canlii.ca/t/gpg9w",
#   "title": "R. v. Safarzadeh‑Markhali",
#   "citation": "[2016] 1 SCR 180, 2016 SCC 14 (CanLII)",
#   "language": "en",
#   "docketNumber": "36162",
#   "decisionDate": "2016-04-15",
#   "keywords": "enhanced credit for pre-sentence custody — offenders — sentencing — challenged provision — bail"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc13",
#   "url": "http://canlii.ca/t/gpg9t",
#   "title": "R. v. Lloyd",
#   "citation": "[2016] 1 SCR 130, 2016 SCC 13 (CanLII)",
#   "language": "en",
#   "docketNumber": "35982",
#   "decisionDate": "2016-04-15",
#   "keywords": "mandatory minimum sentence — one-year mandatory minimum — grossly disproportionate — trafficking — offender"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc12",
#   "url": "http://canlii.ca/t/gpfth",
#   "title": "Daniels v. Canada (Indian Affairs and Northern Development)",
#   "citation": "[2016] 1 SCR 99, 2016 SCC 12 (CanLII)",
#   "language": "en",
#   "docketNumber": "35945",
#   "decisionDate": "2016-04-14",
#   "keywords": "peoples — non-status — federal government — intervener — declaration"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc11",
#   "url": "http://canlii.ca/t/gnzm7",
#   "title": "R. v. Borowiec",
#   "citation": "[2016] 1 SCR 80, 2016 SCC 11 (CanLII)",
#   "language": "en",
#   "docketNumber": "36585",
#   "decisionDate": "2016-03-24",
#   "keywords": "infanticide — disturbed — effects of giving birth — mind — lactation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc10",
#   "url": "http://canlii.ca/t/gnzn9",
#   "title": "R. v. Knapczyk",
#   "citation": "[2016] 1 SCR 78, 2016 SCC 10 (CanLII)",
#   "language": "en",
#   "docketNumber": "36612; 36613",
#   "decisionDate": "2016-03-23",
#   "keywords": "abetted — offence of trafficking through distribution — aided — trafficking in cocaine — convictions"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc8",
#   "url": "http://canlii.ca/t/gnrhl",
#   "title": "Commission scolaire de Laval v. Syndicat de l’enseignement de la région de Laval",
#   "citation": "[2016] 1 SCR 29, 2016 SCC 8 (CanLII)",
#   "language": "en",
#   "docketNumber": "35898",
#   "decisionDate": "2016-03-18",
#   "keywords": "deliberative secrecy — executive committee — arbitrator — camera — principle that motives are unknowable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc7",
#   "url": "http://canlii.ca/t/gnh48",
#   "title": "R. v. Newman",
#   "citation": "[2016] 1 SCR 27, 2016 SCC 7 (CanLII)",
#   "language": "en",
#   "docketNumber": "36524",
#   "decisionDate": "2016-02-26",
#   "keywords": "conviction for first degree murder — forcible confinement — victim from escaping — reinstated — apartment"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "2016scc9",
#   "url": "http://canlii.ca/t/gx77d",
#   "title": "Brine v. Industrial Alliance Insurance and Financial Services Inc.",
#   "citation": "[2016] 1 SCR 72, 2016 SCC 9 (CanLII)",
#   "language": "en",
#   "docketNumber": "36809",
#   "decisionDate": "2016-02-25",
# ...
#   "docketNumber": "22556; 22559",
#   "decisionDate": "1993-10-21",
#   "keywords": "public interest standing — constitutional — retail — challenge — litigants"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii86",
#   "url": "http://canlii.ca/t/1frzq",
#   "title": "R. v. Evans",
#   "citation": "[1993] 3 SCR 653, 1993 CanLII 86 (SCC)",
#   "language": "en",
#   "docketNumber": "22592",
#   "decisionDate": "1993-10-21",
#   "keywords": "statements — hearsay — evidence — getaway vehicle — fencer"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii84",
#   "url": "http://canlii.ca/t/1frzl",
#   "title": "R. v. Ruiz",
#   "citation": "[1993] 3 SCR 649, 1993 CanLII 84 (SCC)",
#   "language": "en",
#   "docketNumber": "23396",
#   "decisionDate": "1993-10-15",
#   "keywords": "discussion of the adverse inference — afterthought — unbelievable — failure to call — abundantly"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii83",
#   "url": "http://canlii.ca/t/1frzj",
#   "title": "R. v. Yorke",
#   "citation": "[1993] 3 SCR 647, 1993 CanLII 83 (SCC)",
#   "language": "en",
#   "docketNumber": "23359",
#   "decisionDate": "1993-10-15",
#   "keywords": "search — dissenting — unreasonable — conducted — manner"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii82",
#   "url": "http://canlii.ca/t/1frzg",
#   "title": "R. v. Gaetz",
#   "citation": "[1993] 3 SCR 645, 1993 CanLII 82 (SCC)",
#   "language": "en",
#   "docketNumber": "23369",
#   "decisionDate": "1993-10-12",
#   "keywords": "indictment — dissenting — fraud — defrauding — exceeding"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii81",
#   "url": "http://canlii.ca/t/1frzd",
#   "title": "R. v. B. (J.G.)",
#   "citation": "[1993] 3 SCR 643, 1993 CanLII 81 (SCC)",
#   "language": "en",
#   "docketNumber": "23320",
#   "decisionDate": "1993-10-08",
#   "keywords": "unreasonable — stay — delay — dismissed — orally"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii80",
#   "url": "http://canlii.ca/t/1frzb",
#   "title": "R. v. Leduc",
#   "citation": "[1993] 3 SCR 641, 1993 CanLII 80 (SCC)",
#   "language": "en",
#   "docketNumber": "23368",
#   "decisionDate": "1993-10-08",
#   "keywords": "abuse of process — decency — clearest — community s sense of fair — fundamental principles of justice"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii79",
#   "url": "http://canlii.ca/t/1frz8",
#   "title": "R. v. Côté",
#   "citation": "[1993] 3 SCR 639, 1993 CanLII 79 (SCC)",
#   "language": "en",
#   "docketNumber": "23067",
#   "decisionDate": "1993-10-07",
#   "keywords": "dissenting — dismissing — iii — conviction — manslaughter"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii78",
#   "url": "http://canlii.ca/t/1frz6",
#   "title": "R. v. Profit",
#   "citation": "[1993] 3 SCR 637, 1993 CanLII 78 (SCC)",
#   "language": "en",
#   "docketNumber": "23313",
#   "decisionDate": "1993-10-07",
#   "keywords": "character evidence as to morality — sexual assault cases involving children — propensity value of character evidence — diminished — indecent"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii77",
#   "url": "http://canlii.ca/t/1frz4",
#   "title": "R. v. Smith",
#   "citation": "[1993] 3 SCR 635, 1993 CanLII 77 (SCC)",
#   "language": "en",
#   "docketNumber": "23304",
#   "decisionDate": "1993-10-06",
#   "keywords": "theft — dishonoured — goods — conviction — payment"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii76",
#   "url": "http://canlii.ca/t/1frz2",
#   "title": "R. v. Price",
#   "citation": "[1993] 3 SCR 633, 1993 CanLII 76 (SCC)",
#   "language": "en",
#   "docketNumber": "23049",
#   "decisionDate": "1993-10-05",
#   "keywords": "intervener — diligence — factors — fresh — evidence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii85",
#   "url": "http://canlii.ca/t/1frzn",
#   "title": "National Party of Canada v. Canadian Broadcasting Corp.",
#   "citation": "[1993] 3 SCR 651, 1993 CanLII 85 (SCC)",
#   "language": "en",
#   "docketNumber": "23726",
#   "decisionDate": "1993-10-04",
#   "keywords": "abridging time — extraordinary situations — abridged — accede — litigants"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii75",
#   "url": "http://canlii.ca/t/1frz0",
#   "title": "Rodriguez v. British Columbia (Attorney General)",
#   "citation": "[1993] 3 SCR 519, 1993 CanLII 75 (SCC)",
#   "language": "en",
#   "docketNumber": "23476",
#   "decisionDate": "1993-09-30",
#   "keywords": "assisted suicide — terminally ill — principles of fundamental justice — life — commit suicide"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii74",
#   "url": "http://canlii.ca/t/1fs14",
#   "title": "R. v. Morgentaler",
#   "citation": "[1993] 3 SCR 463, 1993 CanLII 74 (SCC)",
#   "language": "en",
#   "docketNumber": "22578",
#   "decisionDate": "1993-09-30",
#   "keywords": "legislation — free-standing abortion clinics — privatization — ultra vires — criminal"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii73",
#   "url": "http://canlii.ca/t/1fs12",
#   "title": "Slattery (Trustee of) v. Slattery",
#   "citation": "[1993] 3 SCR 430, 1993 CanLII 73 (SCC)",
#   "language": "en",
#   "docketNumber": "22618",
#   "decisionDate": "1993-09-30",
#   "keywords": "proceedings — enforcement — trustee in bankruptcy — relating to the administration — information"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii72",
#   "url": "http://canlii.ca/t/1fs10",
#   "title": "Ontario Hydro v. Ontario (Labour Relations Board)",
#   "citation": "[1993] 3 SCR 327, 1993 CanLII 72 (SCC)",
#   "language": "en",
#   "docketNumber": "22387; 22355",
#   "decisionDate": "1993-09-30",
#   "keywords": "labour relations — nuclear electrical generating stations — atomic energy — federal — power"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii71",
#   "url": "http://canlii.ca/t/1fs0z",
#   "title": "R. v. Harbottle",
#   "citation": "[1993] 3 SCR 306, 1993 CanLII 71 (SCC)",
#   "language": "en",
#   "docketNumber": "23037",
#   "decisionDate": "1993-09-30",
#   "keywords": "death of the victim — strangled — guilty of first degree murder — causation — forcible confinement"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii70",
#   "url": "http://canlii.ca/t/1fs0w",
#   "title": "R. v. Plant",
#   "citation": "[1993] 3 SCR 281, 1993 CanLII 70 (SCC)",
#   "language": "en",
#   "docketNumber": "22606",
#   "decisionDate": "1993-09-30",
#   "keywords": "warrantless perimeter search — information — electricity — expectation of privacy — police"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii69",
#   "url": "http://canlii.ca/t/1fs0t",
#   "title": "R. v. Wiley",
#   "citation": "[1993] 3 SCR 263, 1993 CanLII 69 (SCC)",
#   "language": "en",
#   "docketNumber": "22804",
#   "decisionDate": "1993-09-30",
#   "keywords": "warrantless perimeter search — marihuana — informant — police — tips"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii68",
#   "url": "http://canlii.ca/t/1fs0r",
#   "title": "R. v. Grant",
#   "citation": "[1993] 3 SCR 223, 1993 CanLII 68 (SCC)",
#   "language": "en",
#   "docketNumber": "23075",
#   "decisionDate": "1993-09-30",
#   "keywords": "warrantless perimeter searches — search — officers — evidence — dwelling-house"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii67",
#   "url": "http://canlii.ca/t/1fs0p",
#   "title": "Edgeworth Construction Ltd. v. N. D. Lea \u0026 Associates Ltd.",
#   "citation": "[1993] 3 SCR 206, 1993 CanLII 67 (SCC)",
#   "language": "en",
#   "docketNumber": "22429",
#   "decisionDate": "1993-09-30",
#   "keywords": "engineers — engineering firm — contract — design — duty of care"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii66",
#   "url": "http://canlii.ca/t/1fs0m",
#   "title": "Auto Concrete Curb Ltd. v. South Nation River Conservation Authority",
#   "citation": "[1993] 3 SCR 201, 1993 CanLII 66 (SCC)",
#   "language": "en",
#   "docketNumber": "23090",
#   "decisionDate": "1993-09-09",
#   "keywords": "contractor — permits — engineer — suction method — sludge"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii65",
#   "url": "http://canlii.ca/t/1fs0k",
#   "title": "R. v. E. (A.W.)",
#   "citation": "[1993] 3 SCR 155, 1993 CanLII 65 (SCC)",
#   "language": "en",
#   "docketNumber": "22810",
#   "decisionDate": "1993-09-09",
#   "keywords": "report — verdict — evidence — charge to the jury — anal intercourse"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii64",
#   "url": "http://canlii.ca/t/1fs0h",
#   "title": "R. v. Naglik",
#   "citation": "[1993] 3 SCR 122, 1993 CanLII 64 (SCC)",
#   "language": "en",
#   "docketNumber": "22490; 22636",
#   "decisionDate": "1993-09-09",
#   "keywords": "failure to provide necessaries — charge to the jury — verdict — penal negligence — mens rea"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii63",
#   "url": "http://canlii.ca/t/1fs0f",
#   "title": "R. v. Finlay",
#   "citation": "[1993] 3 SCR 103, 1993 CanLII 63 (SCC)",
#   "language": "en",
#   "docketNumber": "22596",
#   "decisionDate": "1993-09-09",
#   "keywords": "fault — stigma — offence — ammunition in a careless manner — conviction"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii62",
#   "url": "http://canlii.ca/t/1fs0c",
#   "title": "R. v. Gosset",
#   "citation": "[1993] 3 SCR 76, 1993 CanLII 62 (SCC)",
#   "language": "en",
#   "docketNumber": "22523",
#   "decisionDate": "1993-09-09",
#   "keywords": "jury — negligence — standard of care — unlawful act — marked departure from the standard"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii61",
#   "url": "http://canlii.ca/t/1fs09",
#   "title": "R. v. Creighton",
#   "citation": "[1993] 3 SCR 3, 1993 CanLII 61 (SCC)",
#   "language": "en",
#   "docketNumber": "22593",
#   "decisionDate": "1993-09-09",
#   "keywords": "mens rea — unlawful act manslaughter — risk — bodily harm — death"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii60",
#   "url": "http://canlii.ca/t/1fs08",
#   "title": "Ramsden v. Peterborough (City)",
#   "citation": "[1993] 2 SCR 1084, 1993 CanLII 60 (SCC)",
#   "language": "en",
#   "docketNumber": "22787",
#   "decisionDate": "1993-09-02",
#   "keywords": "freedom of expression — utility poles — by-law — postering on public property — posters"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii59",
#   "url": "http://canlii.ca/t/1fs06",
#   "title": "Murphy v. Welsh; Stoddard v. Watson",
#   "citation": "[1993] 2 SCR 1069, 1993 CanLII 59 (SCC)",
#   "language": "en",
#   "docketNumber": "22601",
#   "decisionDate": "1993-09-02",
#   "keywords": "limitation period — legal disability — motor vehicle — derivative — time"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii58",
#   "url": "http://canlii.ca/t/1fs04",
#   "title": "Haig v. Canada; Haig v. Canada (Chief Electoral Officer)",
#   "citation": "[1993] 2 SCR 995, 1993 CanLII 58 (SCC)",
#   "language": "en",
#   "docketNumber": "23223",
#   "decisionDate": "1993-09-02",
#   "keywords": "ordinarily resident — vote in the federal referendum — freedom of expression — electors — provinces"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii57",
#   "url": "http://canlii.ca/t/1fs27",
#   "title": "R. v. Tortone",
#   "citation": "[1993] 2 SCR 973, 1993 CanLII 57 (SCC)",
#   "language": "en",
#   "docketNumber": "23123",
#   "decisionDate": "1993-09-02",
#   "keywords": "proceeds of narcotic trafficking — declaring a mistrial — proceeds-related charges — counts — evidence"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii115",
#   "url": "http://canlii.ca/t/1fs25",
#   "title": "R. v. Tremblay",
#   "citation": "[1993] 2 SCR 932, 1993 CanLII 115 (SCC)",
#   "language": "en",
#   "docketNumber": "22650",
#   "decisionDate": "1993-09-02",
#   "keywords": "tolerance — dancer — acts — masturbation — community"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii114",
#   "url": "http://canlii.ca/t/1fs23",
#   "title": "R. v. Brown",
#   "citation": "[1993] 2 SCR 918, 1993 CanLII 114 (SCC)",
#   "language": "en",
#   "docketNumber": "23103",
#   "decisionDate": "1993-08-12",
#   "keywords": "silence — undercover — evidence — administration of justice — violation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii113",
#   "url": "http://canlii.ca/t/1fs21",
#   "title": "R. v. Potvin",
#   "citation": "[1993] 2 SCR 880, 1993 CanLII 113 (SCC)",
#   "language": "en",
#   "docketNumber": "23110",
#   "decisionDate": "1993-08-12",
#   "keywords": "appellate delay — stay — process — acquittal — pre-trial"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii112",
#   "url": "http://canlii.ca/t/1fs1z",
#   "title": "Weatherall v. Canada (Attorney General)",
#   "citation": "[1993] 2 SCR 872, 1993 CanLII 112 (SCC)",
#   "language": "en",
#   "docketNumber": "22633",
#   "decisionDate": "1993-08-12",
#   "keywords": "inmates — cross-gender frisk searches — male prisons by female guards — unannounced patrols of cells — intervener"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii111",
#   "url": "http://canlii.ca/t/1fs1w",
#   "title": "R. v. Frazer",
#   "citation": "[1993] 2 SCR 866, 1993 CanLII 111 (SCC)",
#   "language": "en",
#   "docketNumber": "22936",
#   "decisionDate": "1993-08-12",
#   "keywords": "appellate delay — pre-trial delay — unreasonable — bail conditions during the pre-trial — volume"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii110",
#   "url": "http://canlii.ca/t/1fs1t",
#   "title": "R. v. Gallagher",
#   "citation": "[1993] 2 SCR 861, 1993 CanLII 110 (SCC)",
#   "language": "en",
#   "docketNumber": "22966",
#   "decisionDate": "1993-08-12",
#   "keywords": "pre-trial delay — unreasonable — stay — occasion real prejudice — appellate delay"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii109",
#   "url": "http://canlii.ca/t/1fs1r",
#   "title": "R. v. V. (K.B.)",
#   "citation": "[1993] 2 SCR 857, 1993 CanLII 109 (SCC)",
#   "language": "en",
#   "docketNumber": "22944",
#   "decisionDate": "1993-07-15",
#   "keywords": "sexual gratification — sexual assault — dissenting — assault was non-sexual in nature — sexually assaulting his three-year-old"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii108",
#   "url": "http://canlii.ca/t/1fs1p",
#   "title": "Saint-Basile, Village Sud (Corporation municipale de) v. Ciment Québec Inc.",
#   "citation": "[1993] 2 SCR 823, 1993 CanLII 108 (SCC)",
#   "language": "en",
#   "docketNumber": "22749",
#   "decisionDate": "1993-07-15",
#   "keywords": "apparatus — roll — industrial production — building — moveable"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii106",
#   "url": "http://canlii.ca/t/1fs1k",
#   "title": "Domtar Inc. v. Quebec (Commission d\u0027appel en matière de lésions professionnelles)",
#   "citation": "[1993] 2 SCR 756, 1993 CanLII 106 (SCC)",
#   "language": "en",
#   "docketNumber": "22717",
#   "decisionDate": "1993-06-30",
#   "keywords": "patently unreasonable — curial deference — administrative — judicial review — interpretation"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii105",
#   "url": "http://canlii.ca/t/1fs1h",
#   "title": "Canada (Attorney General) v. Ward",
#   "citation": "[1993] 2 SCR 689, 1993 CanLII 105 (SCC)",
#   "language": "en",
#   "docketNumber": "21937",
#   "decisionDate": "1993-06-30",
#   "keywords": "claimant — well-founded fear of persecution — refugee — particular social group — nationality"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii104",
#   "url": "http://canlii.ca/t/1fs1f",
#   "title": "Flieger v. New Brunswick",
#   "citation": "[1993] 2 SCR 651, 1993 CanLII 104 (SCC)",
#   "language": "en",
#   "docketNumber": "22875",
#   "decisionDate": "1993-06-30",
#   "keywords": "discontinuance of a function — employee — ordinary rules of contract — termination — notice"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii103",
#   "url": "http://canlii.ca/t/1fs1c",
#   "title": "R. v. Erickson",
#   "citation": "[1993] 2 SCR 649, 1993 CanLII 103 (SCC)",
#   "language": "en",
#   "docketNumber": "22943",
#   "decisionDate": "1993-06-17",
#   "keywords": "blood-alcohol analysis — administration of justice into disrepute — violation — misapplied — hospitalized"
# }
# {
#   "databaseId": "csc-scc",
#   "caseId": "1993canlii102",
#   "url": "http://canlii.ca/t/1fs19",
#   "title": "R. v. Evans",
#   "citation": "[1993] 2 SCR 629, 1993 CanLII 102 (SCC)",
#   "language": "en",
#   "docketNumber": "22929",
#   "decisionDate": "1993-06-17",
#   "keywords": "jury — gun — evidence — verdict — police"
# }
